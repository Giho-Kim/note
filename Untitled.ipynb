# %%
import wandb

# %%
api = wandb.Api()

# %%
entity = api.default_entity
project = api.projects(entity)[0].name
runs = api.runs(f"{entity}/{project}")

# %%
project
# Out:
# 'maze-fb'

# %%
# from $run.config $df.columns
configs = ['tilt_beta', 'z_mix_ratio', 'tilt_temperature_start', 'seed', 'tilt_init_geom_ratio', 'tilt_candidate_multiplier']
columns = ['eval/reach_top_right/episode_reward_iqm', 'eval/reach_top_left/episode_reward_iqm',
           'eval/reach_bottom_right/episode_reward_iqm','eval/reach_bottom_left/episode_reward_iqm', 
           'eval/task_reward_iqm']

# %%
import pandas as pd

rows = []
log_interval = 20000

for i, run in enumerate(runs):
    print(i, run.state, run.name)
    if run.state == "running":
        continue
    
    df = run.history()
    ckpt = int(run.files()[0].name[:-7]) // log_interval

    row_dict = {}

    for config in configs:
        row_dict[config] = run.config[config]

    for column in columns:
        row_dict[column] = df[column].iloc[ckpt]
        # 또는 df.loc[ckpt, column] 가능, index가 0,1,2...이면

    rows.append(row_dict)

result_df = pd.DataFrame(rows)
# Out:
# 0 finished devoted-darkness-32
# 1 finished vivid-sponge-33
# 2 finished silver-armadillo-34
# 3 finished sparkling-energy-16
# 4 finished crimson-salad-18
# 5 crashed dulcet-lion-29
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 12
#       9     continue
#      11 df = run.history()
# ---> 12 ckpt = int(run.files()[0].name[:-7]) // log_interval
#      14 row_dict = {}
#      16 for config in configs:
#
# ValueError: invalid literal for int() with base 10: 'wandb-metada'

# %%
result_df.to_csv('maze.csv')

# %%
# result_df.groupby(['tilt_init_geom_ratio' ])['eval/task_reward_iqm'].agg(["mean", "std", "count"])
# result_df.groupby(["tilt_temperature_start" ])['eval/task_reward_iqm'].agg(["mean", "std", "count"])
# result_df.groupby(['tilt_candidate_multiplier'])['eval/task_reward_iqm'].agg(["mean", "std", "count"])
result_df.groupby(['z_mix_ratio'])['eval/task_reward_iqm'].agg(["mean", "std", "count"])
# Out:
#                   mean         std  count
# z_mix_ratio
# 0.5          315.47653  115.248025      8

# %%
result_df.groupby(["tilt_temperature_start" , 'tilt_candidate_multiplier'])['eval/task_reward_iqm'].agg(["mean", "std", "count"])
# Out:
#                                                         mean         std  \
# tilt_temperature_start tilt_candidate_multiplier
# 10                     2                          244.905640    2.141387
#                        4                          291.988113  100.334413
# 20                     2                          349.527966  161.922635
#                        4                          375.484400  189.998497
#
#                                                   count
# tilt_temperature_start tilt_candidate_multiplier
# 10                     2                              2
#                        4                              2
# 20                     2                              2
#                        4                              2

# %%
# Out:
# <Runs chicioue512-seoul-national-university/<Project chicioue512-seoul-national-university/uncategorized>>
