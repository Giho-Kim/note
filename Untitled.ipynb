# %%
import wandb

# %%
api = wandb.Api()

# %%
api = wandb.Api()
entity = api.default_entity
project = api.projects(entity)[2].name
runs = api.runs(f"{entity}/{project}")

# %%
project
# Out:
# 'D-LEVER'

# %%
# from $run.config $df.columns
configs = ['tilt_beta', 'z_mix_ratio', 'tilt_temperature_start', 'tilt_temperature_end', 'seed', 'tilt_init_geom_ratio', 'tilt_candidate_multiplier', 'tilt_ridge_alpha']
columns = ['eval/reach_top_right/episode_reward_iqm', 'eval/reach_top_left/episode_reward_iqm',
           'eval/reach_bottom_right/episode_reward_iqm','eval/reach_bottom_left/episode_reward_iqm', 
           'eval/task_reward_iqm']

# %%
import pandas as pd

rows = []
log_interval = 20000

for i, run in enumerate(runs):
    print(i, run.state, run.name)
    if run.state == "running":
        continue
    
    df = run.history()
    ckpt = int(run.files()[0].name[:-7]) // log_interval

    row_dict = {}

    for config in configs:
        row_dict[config] = run.config[config]

    for column in columns:
        row_dict[column] = df[column].iloc[ckpt]
        # 또는 df.loc[ckpt, column] 가능, index가 0,1,2...이면

    rows.append(row_dict)

result_df = pd.DataFrame(rows)
# Out:
# 0 finished devoted-darkness-32
# 1 finished vivid-sponge-33
# 2 finished silver-armadillo-34
# 3 finished sparkling-energy-16
# 4 finished absurd-meadow-4
# 5 finished icy-thunder-5
# 6 finished eager-haze-6
# 7 finished sunny-monkey-10
# 8 finished apricot-salad-11
# 9 finished stoic-resonance-16
# 10 finished noble-shape-17
# 11 finished comfy-bee-14

# %%
# result_df.to_csv('maze.csv')

# %%
result_df = result_df[result_df['tilt_candidate_multiplier']==2 ]

# %%
result_df.groupby(["tilt_temperature_start" ,'tilt_ridge_alpha', 'seed'])['eval/task_reward_iqm'].agg(["mean", "std", "count"])
# Out:
#                                                     mean  std  count
# tilt_temperature_start tilt_ridge_alpha seed
# 10                     0.01             42    404.931381  NaN      1
#                                         43    261.707348  NaN      1
#                        0.10             42    389.482758  NaN      1
#                                         43    435.136925  NaN      1
# 20                     0.01             42    485.403229  NaN      1
#                                         43    298.899964  NaN      1
#                        0.10             42    235.031372  NaN      1
#                                         43    464.024559  NaN      1

# %%
columns = ['eval/reach_top_right/episode_reward_iqm', 'eval/reach_top_left/episode_reward_iqm',
           'eval/reach_bottom_right/episode_reward_iqm','eval/reach_bottom_left/episode_reward_iqm', 
           'eval/task_reward_iqm']

# %%
result_df.groupby(["tilt_temperature_start" ,'tilt_ridge_alpha'])[columns].agg(["mean"])
# Out:
#                                         eval/reach_top_right/episode_reward_iqm  \
#                                                                            mean
# tilt_temperature_start tilt_ridge_alpha
# 10                     0.01                                          376.831177
#                        0.10                                          220.662552
# 20                     0.01                                          259.996780
#                        0.10                                          128.468246
#
#                                         eval/reach_top_left/episode_reward_iqm  \
#                                                                           mean
# tilt_temperature_start tilt_ridge_alpha
# 10                     0.01                                         558.583122
#                        0.10                                         913.689880
# 20                     0.01                                         919.776581
#                        0.10                                         910.455048
#
#                                         eval/reach_bottom_right/episode_reward_iqm  \
#                                                                               mean
# tilt_temperature_start tilt_ridge_alpha
# 10                     0.01                                                    0.0
#                        0.10                                                    0.0
# 20                     0.01                                                    0.0
#                        0.10                                                    0.0
#
#                                         eval/reach_bottom_left/episode_reward_iqm  \
#                                                                              mean
# tilt_temperature_start tilt_ridge_alpha
# 10                     0.01                                            397.863159
#                        0.10                                            514.886932
# 20                     0.01                                            388.833025
#                        0.10                                            359.188568
#
#                                         eval/task_reward_iqm
#                                                         mean
# tilt_temperature_start tilt_ridge_alpha
# 10                     0.01                       333.319365
#                        0.10                       412.309841
# 20                     0.01                       392.151597
#                        0.10                       349.527966

# %%
# Out:
# 'eval/reach_top_right/episode_reward_iqm'

# %% [markdown]
# # D-lever

# %%
api = wandb.Api()
entity = api.default_entity
project = api.projects(entity)[2].name
runs = api.runs(f"{entity}/{project}")
project
# Out:
# 'D-LEVER'

# %%
# from $run.config $df.columns
configs = ['domain_name', 'tilt', 'tilt_ridge_alpha', 'tilt_temperature_start',  'tilt_temperature_end','seed']
columns = ['eval/task_reward_iqm']
col = 'eval/task_reward_iqm'

# %%
import pandas as pd

rows = []
log_interval = 20000

for i, run in enumerate(runs):
    print(i, run.state, run.name)
    if run.state == "running" or run.state == "crashed": # or run.config["algorithm"] == 'fb':
        continue
    
    df = run.history()
#     ckpt = int(run.files()[0].name[:-7]) // log_interval
    ckpt = df[col].argmax()
    
    
    row_dict = {}

    for config in configs:
        row_dict[config] = run.config[config]

    for column in columns:
        row_dict[column] = df[column].iloc[ckpt]
        # 또는 df.loc[ckpt, column] 가능, index가 0,1,2...이면

    rows.append(row_dict)

result_df = pd.DataFrame(rows)
# Out:
# 0 finished wise-armadillo-99
# 1 finished happy-cloud-102
# 2 finished light-gorge-103
# 3 finished avid-sun-104
# 4 finished sunny-blaze-23
# 5 finished icy-frog-24
# 6 finished clear-silence-25
# 7 finished frosty-pond-34
# 8 finished upbeat-butterfly-36
# 9 finished wobbly-dawn-37
# 10 finished iconic-terrain-41
# 11 finished ruby-wood-53
# 12 finished crimson-dew-57
# 13 finished misunderstood-armadillo-58
# 14 finished treasured-bee-59
# 15 finished blooming-lake-60
# 16 finished glorious-monkey-61
# 17 finished apricot-snow-68
# 18 finished glowing-river-72
# 19 finished lunar-vortex-73
# 20 finished zesty-field-74
# 21 finished pious-donkey-75
# 22 finished upbeat-smoke-76
# 23 finished smart-dragon-77
# 24 finished stilted-forest-78
# 25 finished classic-river-80
# 26 finished avid-cosmos-81
# 27 finished genial-moon-82
# 28 finished smooth-water-85
# 29 finished genial-lion-86
# 30 finished swept-bee-87
# 31 finished wandering-flower-88
# 32 finished decent-oath-89
# 33 finished trim-wildflower-105
# 34 finished rich-hill-106
# 35 finished fast-vortex-107
# 36 finished icy-wood-108
# 37 finished true-energy-111
# 38 finished youthful-snowball-112
# 39 finished confused-plasma-113
# 40 finished wandering-cloud-114
# 41 finished revived-lake-115
# 42 finished glad-resonance-116
# 43 finished bright-monkey-117
# 44 finished earthy-valley-118
# 45 finished warm-monkey-119
# 46 finished usual-totem-120
# 47 finished super-serenity-121
# 48 finished upbeat-vortex-122
# 49 finished faithful-dragon-123
# 50 finished dainty-vortex-124
# 51 finished morning-water-125
# 52 finished wild-salad-126
# 53 finished confused-armadillo-127
# 54 crashed stilted-sea-130

# %%
configs = ['domain_name', 'tilt', 'tilt_ridge_alpha', 'tilt_temperature_start']

# %%
# result_df.groupby(configs)[col].agg(["mean",  "sem", "count"])#"std", "count",
result_df.groupby(configs)[col].agg(["mean",  "sem", "count"])#"std", "count",
# Out:
#                                                                 mean  \
# domain_name tilt tilt_ridge_alpha tilt_temperature_start
# jaco        True 0.001            10                       16.572269
#                                   20                       22.301228
#                  0.010            10                       17.426674
#                                   20                       13.910865
#                  0.100            10                       23.867574
#                                   20                       16.334526
# quadruped   True 0.001            10                      562.958323
#                                   20                      560.407005
#                  0.010            10                      573.837134
#                                   20                      465.393796
#                  0.100            10                      503.469980
#                                   20                      454.052903
# walker      True 0.001            10                      409.677928
#                                   20                      421.367334
#                  0.010            10                      283.691155
#                                   20                      405.344055
#                  0.100            10                      397.977894
#                                   20                      366.081576
#
#                                                                  sem  count
# domain_name tilt tilt_ridge_alpha tilt_temperature_start
# jaco        True 0.001            10                        2.324257      3
#                                   20                        1.404423      3
#                  0.010            10                        2.863727      3
#                                   20                        1.698739      3
#                  0.100            10                        2.080802      3
#                                   20                        2.762071      3
# quadruped   True 0.001            10                       12.292458      3
#                                   20                       43.827487      3
#                  0.010            10                       27.202463      3
#                                   20                      116.662923      3
#                  0.100            10                       88.019122      3
#                                   20                       92.350216      3
# walker      True 0.001            10                       12.102873      3
#                                   20                       47.223527      3
#                  0.010            10                       99.413085      3
#                                   20                        5.613331      3
#                  0.100            10                       48.086877      3
#                                   20                       45.863220      3

# %%
# # result_df.groupby(configs)[col].agg(["mean",  "sem", "count"])#"std", "count",
# result_df.groupby(configs)[col].agg(["mean",  "sem", "count"])#"std", "count",
# Out:
#                                                                     mean  \
# domain_name     tilt tilt_ridge_alpha tilt_temperature_start
# point_mass_maze True 0.001            10                      310.055038
#                                       20                      361.975184
#                      0.010            10                      353.387679
#                                       20                      352.701357
#                      0.100            10                      353.514834
#                                       20                      311.783873
#
#                                                                     sem  count
# domain_name     tilt tilt_ridge_alpha tilt_temperature_start
# point_mass_maze True 0.001            10                      42.568726      3
#                                       20                      41.971976      3
#                      0.010            10                      45.958288      3
#                                       20                      66.745365      3
#                      0.100            10                      60.254002      3
#                                       20                      76.121218      3

# %%
df_group_by = result_df.groupby(configs)[col].agg(["mean",  "sem"]).to_csv("result.csv")

# %% [markdown]
# # D-LEVER-MAZE

# %%
api = wandb.Api()
entity = api.default_entity
project = api.projects(entity)[0].name
runs = api.runs(f"{entity}/{project}")
project
# Out:
# 'D-LEVER'

# %%
# from $run.config $df.columns
configs = ['domain_name', 'tilt', 'tilt_ridge_alpha', 'tilt_temperature_start', 'seed']
columns = ['eval/task_reward_iqm','eval/reach_top_left/episode_reward_iqm',
'eval/reach_top_right/episode_reward_iqm',
'eval/reach_bottom_left/episode_reward_iqm',
'eval/reach_bottom_right/episode_reward_iqm',
           ]
col = 'eval/task_reward_iqm'

# %%
import pandas as pd

rows = []
log_interval = 20000

for i, run in enumerate(runs):
#     break
    df = run.history()
    
    if run.state == "running" or run.config["domain_name"] != 'point_mass_maze' or len(df) < 50:
        continue
    print(i, run.state, run.name, run.config["domain_name"])

    ckpt = df[col].argmax()
    

    row_dict = {}

    for config in configs:
        row_dict[config] = run.config[config]

    for column in columns:
        row_dict[column] = df[column].iloc[ckpt]

    rows.append(row_dict)

result_df = pd.DataFrame(rows)
# Out:
# 2 finished helpful-oath-3 point_mass_maze
# 10 finished wild-dew-11 point_mass_maze
# 18 finished snowy-fog-19 point_mass_maze
# 25 finished dainty-terrain-26 point_mass_maze
# 33 finished treasured-silence-34 point_mass_maze
# 40 finished fearless-silence-41 point_mass_maze
# 48 finished crimson-pine-49 point_mass_maze
# 56 finished royal-puddle-57 point_mass_maze
# 57 finished twilight-flower-58 point_mass_maze
# 58 finished glorious-dawn-59 point_mass_maze
# 59 finished dutiful-firebrand-60 point_mass_maze
# 60 finished crimson-bush-64 point_mass_maze
# 61 finished bright-wave-65 point_mass_maze
# 62 finished glorious-dragon-66 point_mass_maze
# 65 finished summer-plasma-77 point_mass_maze
# 68 finished zesty-dust-80 point_mass_maze
# 71 finished sleek-violet-83 point_mass_maze
# 72 finished fine-music-84 point_mass_maze
# 74 finished jumping-morning-86 point_mass_maze
# 78 finished stellar-universe-90 point_mass_maze

# %%
configs = ['domain_name', 'tilt', 'tilt_ridge_alpha', 'tilt_temperature_start']#, 'seed']
columns = ['eval/task_reward_iqm','eval/reach_top_left/episode_reward_iqm',
'eval/reach_top_right/episode_reward_iqm',
'eval/reach_bottom_left/episode_reward_iqm',
'eval/reach_bottom_right/episode_reward_iqm',]
with pd.option_context('display.float_format', '{:.3f}'.format):
    display(result_df.groupby(configs)[columns].agg(["mean", "count"]))
# Out:
#                                                               eval/task_reward_iqm  \
#                                                                               mean
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                                  148.525
#                 True  0.001            10                                  161.427
#                                        20                                  171.654
#                       0.010            10                                  193.206
#                                        20                                  127.651
#                       0.100            10                                  137.443
#                                        20                                  190.910
#
#                                                                      \
#                                                               count
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                         3
#                 True  0.001            10                         3
#                                        20                         2
#                       0.010            10                         3
#                                        20                         3
#                       0.100            10                         3
#                                        20                         3
#
#                                                               eval/reach_top_left/episode_reward_iqm  \
#                                                                                                 mean
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                                                    418.342
#                 True  0.001            10                                                    434.039
#                                        20                                                    347.525
#                       0.010            10                                                    472.865
#                                        20                                                    247.894
#                       0.100            10                                                    298.862
#                                        20                                                    593.869
#
#                                                                      \
#                                                               count
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                         3
#                 True  0.001            10                         3
#                                        20                         2
#                       0.010            10                         3
#                                        20                         3
#                       0.100            10                         3
#                                        20                         3
#
#                                                               eval/reach_top_right/episode_reward_iqm  \
#                                                                                                  mean
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                                                       0.004
#                 True  0.001            10                                                     121.396
#                                        20                                                     259.139
#                       0.010            10                                                      66.851
#                                        20                                                     179.030
#                       0.100            10                                                     130.764
#                                        20                                                     169.772
#
#                                                                      \
#                                                               count
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                         3
#                 True  0.001            10                         3
#                                        20                         2
#                       0.010            10                         3
#                                        20                         3
#                       0.100            10                         3
#                                        20                         3
#
#                                                               eval/reach_bottom_left/episode_reward_iqm  \
#                                                                                                    mean
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                                                       175.755
#                 True  0.001            10                                                        90.273
#                                        20                                                        79.952
#                       0.010            10                                                       230.674
#                                        20                                                        83.678
#                       0.100            10                                                       120.147
#                                        20                                                         0.000
#
#                                                                      \
#                                                               count
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                         3
#                 True  0.001            10                         3
#                                        20                         2
#                       0.010            10                         3
#                                        20                         3
#                       0.100            10                         3
#                                        20                         3
#
#                                                               eval/reach_bottom_right/episode_reward_iqm  \
#                                                                                                     mean
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                                                          0.000
#                 True  0.001            10                                                          0.000
#                                        20                                                          0.000
#                       0.010            10                                                          2.433
#                                        20                                                          0.000
#                       0.100            10                                                          0.000
#                                        20                                                          0.000
#
#
#                                                               count
# domain_name     tilt  tilt_ridge_alpha tilt_temperature_start
# point_mass_maze False 0.001            20                         3
#                 True  0.001            10                         3
#                                        20                         2
#                       0.010            10                         3
#                                        20                         3
#                       0.100            10                         3
#                                        20                         3
